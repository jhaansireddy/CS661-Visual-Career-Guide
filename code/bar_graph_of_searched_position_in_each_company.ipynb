# %%
import dash
from dash import dcc
from dash import html
import pandas as pd
import dash
from dash.dependencies import Input, Output
import plotly.express as px
from dash import dcc, html

df = pd.read_csv('job_skills.csv')
df1 = pd.read_csv('linkedin_job_postings.csv')
linkedin_job = pd.merge(df1, df, on = 'job_link', how = 'inner')
linkedin_job = linkedin_job.dropna()
linkedin_job.shape[0]


companies = df1['company'].dropna().unique()
# linkedin_job.head()
filtered_data = df1[df1['company']=='BD']
job_titles = filtered_data['search_position'].value_counts()
for job_title, count in job_titles.items():
        print(f"{job_title}:{count}")

linkedin_job.head()
# Out:
# Color Maker:13
# Account Executive:2
# Solutions Operator:2
# Industrial Engineer:2
# Mill Operator:1
# Manager Stage:1
# Part Maker:1
# Supervisor Chemical:1
# Manager Employment:1
# Manager Benefits:1
# Electrical Inspector:1
# Bricklayer Supervisor:1
# Developer:1
# Scheduler:1
# Commercial Engineer:1
# Plumber:1
# Supervisor Laboratory:1
# Liaison Engineer:1
# Central-Office Equipment Engineer:1
# Accountant Cost:1
# Field Contractor:1
# Manager Records Analysis:1
# Set-Key Driver:1
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/account-exe...
# 1  https://www.linkedin.com/jobs/view/registered-...
# 2  https://www.linkedin.com/jobs/view/restaurant-...
# 3  https://www.linkedin.com/jobs/view/independent...
# 4  https://www.linkedin.com/jobs/view/registered-...
#
#              last_processed_time got_summary got_ner is_being_worked  \
# 0   2024-01-21 07:12:29.00256+00           t       t               f
# ...

# %%
top_jobs=linkedin_job["job_title"].value_counts().head(10)
top_jobs
app = dash.Dash()

# %%
import dash
from dash import dcc, html
import pandas as pd
from dash.dependencies import Input, Output
import plotly.graph_objs as go

# Assuming df1 is already defined
df1 = pd.read_csv('linkedin_job_postings.csv')

selected_company = [
    'BD',
    'Trinity Health MI',
]

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H3('Choose Company'),
    dcc.Dropdown(
        id='company-dropdown',
        options=[{'label': company, 'value': company} for company in selected_company],
        value=selected_company[0],
        style={'width': '50%'}
    ),
    dcc.Graph(id='company-comparison-chart')
])

@app.callback(
    Output('company-comparison-chart', 'figure'),
    [Input('company-dropdown', 'value')]
)
def update_chart(selected_company):
    company_data = df1[df1['company'] == selected_company]
    job_counts = company_data['search_position'].value_counts()

    # Create a bar graph
    bar_data = go.Bar(x=job_counts.index, y=job_counts.values)

    # Layout for the bar graph
    layout = go.Layout(title=f'Job Titles Distribution for {selected_company}',
                       xaxis={'title': 'Job Title'},
                       yaxis={'title': 'Count'})

    return {'data': [bar_data], 'layout': layout}

if __name__ == "__main__":
    app.run_server(debug=True, port = 5091)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5091/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
if __name__ == "__main__": #flash framework
    app.run_server(port = 5050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
help(dcc.Dropdown)
# Out:
# Help on class Dropdown in module dash.dcc.Dropdown:
#
# class Dropdown(dash.development.base_component.Component)
#  |  Dropdown(options=undefined, value=undefined, multi=undefined, clearable=undefined, searchable=undefined, search_value=undefined, placeholder=undefined, disabled=undefined, optionHeight=undefined, maxHeight=undefined, style=undefined, className=undefined, id=undefined, loading_state=undefined, persistence=undefined, persisted_props=undefined, persistence_type=undefined, **kwargs)
#  |
#  |  A Dropdown component.
#  |  Dropdown is an interactive dropdown element for selecting one or more
#  |  items.
#  |  The values and labels of the dropdown items are specified in the `options`
#  |  property and the selected item(s) are specified with the `value` property.
#  |
#  |  Use a dropdown when you have many options (more than 5) or when you are
#  |  constrained for space. Otherwise, you can use RadioItems or a Checklist,
# ...

# %%
import dash
from dash import dcc, html
import pandas as pd
from dash.dependencies import Input, Output
import plotly.graph_objs as go

# Assuming df1 is already defined
df= pd.read_csv('job_skills.csv')
df0 = pd.read_csv('linkedin_job_postings.csv')
df1 =pd.merge(df0, df, on = 'job_link', how = 'inner')

# Get all unique companies from the dataset
selected_company = df1['company'].dropna().unique()

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H3('Choose Company'),
    dcc.Dropdown(
        id='company-dropdown',
        options=[{'label': company, 'value': company} for company in selected_company],
        value=selected_company[0],
        style={'width': '50%'}
    ),
    dcc.Graph(id='company-comparison-chart')
])

@app.callback(
    Output('company-comparison-chart', 'figure'),
    [Input('company-dropdown', 'value')]
)
def update_chart(selected_company):
    company_data = df1[df1['company'] == selected_company]
    job_counts = company_data['search_position'].value_counts()

    # Create a bar graph
    bar_data = go.Bar(x=job_counts.index, y=job_counts.values)

    # Layout for the bar graph
    layout = go.Layout(title=f'Search Position Distribution for {selected_company}',
                       xaxis={'title': 'Search Position'},
                       yaxis={'title': 'Count'})

    return {'data': [bar_data], 'layout': layout}

if __name__ == "__main__":
    app.run_server(debug=True, port=5091)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5091/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
